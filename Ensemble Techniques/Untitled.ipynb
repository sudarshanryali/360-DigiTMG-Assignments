# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Coca_Rating_Ensemble_ (1).csv")
df
# Out:
#        Company                Name   REF  Review Cocoa_Percent  \
# 0     A. Morin         Agua Grande  1876    2016           63%
# 1     A. Morin               Kpime  1676    2015           70%
# 2     A. Morin              Atsane  1676    2015           70%
# 3     A. Morin               Akata  1680    2015           70%
# 4     A. Morin              Quilla  1704    2015           70%
# ...        ...                 ...   ...     ...           ...
# 1790    Zotter                Peru   647    2011           70%
# 1791    Zotter               Congo   749    2011           65%
# 1792    Zotter        Kerala State   749    2011           65%
# 1793    Zotter        Kerala State   781    2011           62%
# 1794    Zotter  Brazil, Mitzi Blue   486    2010           65%
#
#      Company_Location  Rating  Bean_Type    Origin
# 0              France    3.75          ÿ  Sao Tome
# 1              France    2.75          ÿ      Togo
# 2              France    3.00          ÿ      Togo
# ...

# %%
df.describe()
# Out:
#                REF       Review       Rating
# count  1795.000000  1795.000000  1795.000000
# mean   1035.904735  2012.325348     3.185933
# std     552.886365     2.927210     0.478062
# min       5.000000  2006.000000     1.000000
# 25%     576.000000  2010.000000     2.875000
# 50%    1069.000000  2013.000000     3.250000
# 75%    1502.000000  2015.000000     3.500000
# max    1952.000000  2017.000000     5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1795 non-null   object
#  1   Name              1795 non-null   object
#  2   REF               1795 non-null   int64
#  3   Review            1795 non-null   int64
#  4   Cocoa_Percent     1795 non-null   object
#  5   Company_Location  1795 non-null   object
#  6   Rating            1795 non-null   float64
#  7   Bean_Type         1794 non-null   object
#  8   Origin            1794 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
df['Bean_Type'].mode().fillna
# Out:
# <bound method Series.fillna of 0    ÿ
# dtype: object>

# %%
x=df.drop(['Bean_Type'],axis=1)
x
# Out:
#        Company                Name   REF  Review Cocoa_Percent  \
# 0     A. Morin         Agua Grande  1876    2016           63%
# 1     A. Morin               Kpime  1676    2015           70%
# 2     A. Morin              Atsane  1676    2015           70%
# 3     A. Morin               Akata  1680    2015           70%
# 4     A. Morin              Quilla  1704    2015           70%
# ...        ...                 ...   ...     ...           ...
# 1790    Zotter                Peru   647    2011           70%
# 1791    Zotter               Congo   749    2011           65%
# 1792    Zotter        Kerala State   749    2011           65%
# 1793    Zotter        Kerala State   781    2011           62%
# 1794    Zotter  Brazil, Mitzi Blue   486    2010           65%
#
#      Company_Location  Rating    Origin
# 0              France    3.75  Sao Tome
# 1              France    2.75      Togo
# 2              France    3.00      Togo
# 3              France    3.50      Togo
# ...

# %%
y=df['Bean_Type']
y
# Out:
# 0               ÿ
# 1               ÿ
# 2               ÿ
# 3               ÿ
# 4               ÿ
#           ...
# 1790            ÿ
# 1791    Forastero
# 1792    Forastero
# 1793            ÿ
# 1794            ÿ
# Name: Bean_Type, Length: 1795, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Name']=le.fit_transform(df['Name'])

# %%
df['Company']=le.fit_transform(df['Company'])

# %%
df['Cocoa_Percent']=le.fit_transform(df['Cocoa_Percent'])

# %%
df['Origin'] = le.fit_transform(df["Origin"].astype(str))

# %%
df['Company_Location']=le.fit_transform(df['Company_Location'])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8, random_state=0)

# %%
from sklearn.ensemble import BaggingClassifier

# %%
clf=BaggingClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-23a7f0d6d621> in <module>
# ----> 1 clf.fit(x_train,y_train)
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_bagging.py in fit(self, X, y, sample_weight)
#     241         self : object
#     242         """
# --> 243         return self._fit(X, y, self.max_samples, sample_weight=sample_weight)
#     244
#     245     def _parallel_args(self):
#
# D:\Anaconda\lib\site-packages\sklearn\ensemble\_bagging.py in _fit(self, X, y, max_samples, max_depth, sample_weight)
#     279
#     280         # Convert data (X is required to be 2d and indexable)
# --> 281         X, y = self._validate_data(
#     282             X, y, accept_sparse=['csr', 'csc'], dtype=None,
#     283             force_all_finite=False, multi_output=True
#
# ...
